# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('DadosVoo (1).csv').head(1000)

# %%
data
# Out:
#           Voos        Companhia.Aerea Codigo.Tipo.Linha      Partida.Prevista  \
# 0    AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-30T08:58:00Z
# 1    AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-13T12:13:00Z
# 2    AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-29T12:13:00Z
# 3    AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-19T12:13:00Z
# 4    AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-30T12:13:00Z
# 5    AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-03T23:05:00Z
# 6    AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-05T23:05:00Z
# 7    AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-18T12:13:00Z
# 8    AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-22T23:05:00Z
# 9    AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-15T23:05:00Z
# 10   AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-10T08:58:00Z
# ...

# %%
data.columns
# Out:
# Index(['Voos', 'Companhia.Aerea', 'Codigo.Tipo.Linha', 'Partida.Prevista',
#        'Partida.Real', 'Chegada.Prevista', 'Chegada.Real', 'Situacao.Voo',
#        'Codigo.Justificativa', 'Aeroporto.Origem', 'Cidade.Origem',
#        'Estado.Origem', 'Pais.Origem', 'Aeroporto.Destino', 'Cidade.Destino',
#        'Estado.Destino', 'Pais.Destino', 'LongDest', 'LatDest', 'LongOrig',
#        'LatOrig'],
#       dtype='object')

# %%
data.shape
# Out:
# (999, 21)

# %%
# Selecionando Colunas especificas
data=pd.read_csv('DadosVoo (1).csv',header=0,usecols=['Voos','Partida.Prevista'],nrows=100)

# %%
data
# Out:
#          Voos      Partida.Prevista
# 0   AAL - 203  2016-01-30T08:58:00Z
# 1   AAL - 203  2016-01-13T12:13:00Z
# 2   AAL - 203  2016-01-29T12:13:00Z
# 3   AAL - 203  2016-01-19T12:13:00Z
# 4   AAL - 203  2016-01-30T12:13:00Z
# 5   AAL - 203  2016-01-03T23:05:00Z
# 6   AAL - 203  2016-01-05T23:05:00Z
# 7   AAL - 203  2016-01-18T12:13:00Z
# 8   AAL - 203  2016-01-22T23:05:00Z
# 9   AAL - 203  2016-01-15T23:05:00Z
# 10  AAL - 203  2016-01-10T08:58:00Z
# 11  AAL - 203  2016-01-24T12:13:00Z
# 12  AAL - 203  2016-01-05T08:58:00Z
# 13  AAL - 203  2016-01-18T08:58:00Z
# 14  AAL - 203  2016-01-31T08:58:00Z
# 15  AAL - 203  2016-01-26T23:05:00Z
# 16  AAL - 203  2016-01-12T08:58:00Z
# 17  AAL - 203  2016-01-07T12:13:00Z
# 18  AAL - 203  2016-01-21T23:05:00Z
# 19  AAL - 203  2016-01-29T23:05:00Z
# 20  AAL - 203  2016-01-11T23:05:00Z
# 21  AAL - 203  2016-01-21T12:13:00Z
# 22  AAL - 203  2016-01-10T12:13:00Z
# 23  AAL - 203  2016-01-02T12:13:00Z
# 24  AAL - 203  2016-01-09T08:58:00Z
# ...

# %%
#ler o tipo de dados de cada coluna utiliza-se dtypes
data.dtypes
# Out:
# Voos                     object
# Companhia.Aerea          object
# Codigo.Tipo.Linha        object
# Partida.Prevista         object
# Partida.Real             object
# Chegada.Prevista         object
# Chegada.Real             object
# Situacao.Voo             object
# Codigo.Justificativa     object
# Aeroporto.Origem         object
# Cidade.Origem            object
# Estado.Origem            object
# Pais.Origem              object
# Aeroporto.Destino        object
# Cidade.Destino           object
# Estado.Destino           object
# Pais.Destino             object
# LongDest                float64
# LatDest                 float64
# LongOrig                float64
# LatOrig                 float64
# dtype: object

# %%
#Escolhendo mais de uma coluna
data[['Voos','Pais.Origem']]
# Out:
#           Voos     Pais.Origem
# 0    AAL - 203          Brasil
# 1    AAL - 203          Brasil
# 2    AAL - 203          Brasil
# 3    AAL - 203          Brasil
# 4    AAL - 203          Brasil
# 5    AAL - 203  Estados Unidos
# 6    AAL - 203  Estados Unidos
# 7    AAL - 203          Brasil
# 8    AAL - 203  Estados Unidos
# 9    AAL - 203  Estados Unidos
# 10   AAL - 203          Brasil
# 11   AAL - 203          Brasil
# 12   AAL - 203          Brasil
# 13   AAL - 203          Brasil
# 14   AAL - 203          Brasil
# 15   AAL - 203  Estados Unidos
# 16   AAL - 203          Brasil
# 17   AAL - 203          Brasil
# 18   AAL - 203  Estados Unidos
# 19   AAL - 203  Estados Unidos
# 20   AAL - 203  Estados Unidos
# 21   AAL - 203          Brasil
# 22   AAL - 203          Brasil
# 23   AAL - 203          Brasil
# 24   AAL - 203          Brasil
# 25   AAL - 203          Brasil
# 26   AAL - 203          Brasil
# 27   AAL - 203          Brasil
# 28   AAL - 203  Estados Unidos
# ...

# %%
# Usando ponto(.) como notação 
data.Voos
# Out:
# 0     AAL - 203
# 1     AAL - 203
# 2     AAL - 203
# 3     AAL - 203
# 4     AAL - 203
# 5     AAL - 203
# 6     AAL - 203
# 7     AAL - 203
# 8     AAL - 203
# 9     AAL - 203
# 10    AAL - 203
# 11    AAL - 203
# 12    AAL - 203
# 13    AAL - 203
# 14    AAL - 203
# 15    AAL - 203
# 16    AAL - 203
# 17    AAL - 203
# 18    AAL - 203
# 19    AAL - 203
# 20    AAL - 203
# 21    AAL - 203
# 22    AAL - 203
# 23    AAL - 203
# 24    AAL - 203
# 25    AAL - 203
# 26    AAL - 203
# 27    AAL - 203
# 28    AAL - 203
# 29    AAL - 203
#         ...
# 70    AAL - 203
# 71    AAL - 203
# 72    AAL - 203
# 73    AAL - 203
# 74    AAL - 203
# 75    AAL - 203
# 76    AAL - 203
# 77    AAL - 203
# 78    AAL - 203
# 79    AAL - 203
# 80    AAL - 203
# 81    AAL - 203
# 82    AAL - 203
# 83    AAL - 203
# 84    AAL - 203
# 85    AAL - 203
# 86    AAL - 203
# 87    AAL - 203
# 88    AAL - 203
# 89    AAL - 203
# 90    AAL - 203
# 91    AAL - 203
# 92    AAL - 203
# 93    AAL - 213
# ...

# %%
# Usando a função loc
data.loc[0:10]
# Out:
#          Voos        Companhia.Aerea Codigo.Tipo.Linha      Partida.Prevista  \
# 0   AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-30T08:58:00Z
# 1   AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-13T12:13:00Z
# 2   AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-29T12:13:00Z
# 3   AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-19T12:13:00Z
# 4   AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-30T12:13:00Z
# 5   AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-03T23:05:00Z
# 6   AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-05T23:05:00Z
# 7   AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-18T12:13:00Z
# 8   AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-22T23:05:00Z
# 9   AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-15T23:05:00Z
# 10  AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-01-10T08:58:00Z
#
# ...

# %%
#Usando o sort_values
#Utilizado para filtrar do menor para o maior
data.sort_values('Chegada.Real').head(15)
# Out:
#           Voos        Companhia.Aerea Codigo.Tipo.Linha      Partida.Prevista  \
# 613  AAL - 964  AMERICAN AIRLINES INC     Internacional  2016-01-01T02:38:00Z
# 119  AAL - 213  AMERICAN AIRLINES INC     Internacional  2016-01-01T00:29:00Z
# 271  AAL - 273  AMERICAN AIRLINES INC     Internacional  2016-01-01T00:54:00Z
# 407  AAL - 906  AMERICAN AIRLINES INC     Internacional  2016-01-01T01:30:00Z
# 369  AAL - 905  AMERICAN AIRLINES INC     Internacional  2016-01-01T00:49:00Z
# 436  AAL - 907  AMERICAN AIRLINES INC     Internacional  2016-01-01T00:50:00Z
# 714  AAL - 991  AMERICAN AIRLINES INC     Internacional  2016-01-01T01:30:00Z
# 649  AAL - 973  AMERICAN AIRLINES INC     Internacional  2016-01-01T00:35:00Z
# 536  AAL - 951  AMERICAN AIRLINES INC     Internacional  2016-01-01T01:30:00Z
# 794  AAL - 995  AMERICAN AIRLINES INC     Internacional  2016-01-01T00:55:00Z
# 860   ACA - 90             AIR CANADA     Internacional  2016-01-01T01:45:00Z
# ...

# %%
# Usando o sort_values com mais de uma coluna
data.sort_values(['Chegada.Prevista','Partida.Prevista']).head(5)
# Out:
#           Voos        Companhia.Aerea Codigo.Tipo.Linha      Partida.Prevista  \
# 119  AAL - 213  AMERICAN AIRLINES INC     Internacional  2016-01-01T00:29:00Z
# 613  AAL - 964  AMERICAN AIRLINES INC     Internacional  2016-01-01T02:38:00Z
# 271  AAL - 273  AMERICAN AIRLINES INC     Internacional  2016-01-01T00:54:00Z
# 794  AAL - 995  AMERICAN AIRLINES INC     Internacional  2016-01-01T00:55:00Z
# 369  AAL - 905  AMERICAN AIRLINES INC     Internacional  2016-01-01T00:49:00Z
#
#              Partida.Real      Chegada.Prevista          Chegada.Real  \
# 119  2016-01-01T00:29:00Z  2016-01-01T07:56:00Z  2016-01-01T07:56:00Z
# 613  2016-01-01T02:09:00Z  2016-01-01T08:04:00Z  2016-01-01T07:26:00Z
# 271  2016-01-01T00:52:00Z  2016-01-01T08:56:00Z  2016-01-01T08:03:00Z
# 794  2016-01-01T02:46:00Z  2016-01-01T09:25:00Z  2016-01-01T10:51:00Z
# 369  2016-01-01T00:49:00Z  2016-01-01T09:27:00Z  2016-01-01T09:27:00Z
#
# ...

# %%
# Usando sort_values para classificar por ordem decrescente
data.sort_values('Chegada.Prevista',ascending= False).head()
# Out:
#           Voos        Companhia.Aerea Codigo.Tipo.Linha      Partida.Prevista  \
# 92   AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-02-01T12:13:00Z
# 87   AAL - 203  AMERICAN AIRLINES INC     Internacional  2016-02-01T08:58:00Z
# 889   ACA - 91             AIR CANADA     Internacional  2016-01-31T22:35:00Z
# 671  AAL - 974  AMERICAN AIRLINES INC     Internacional  2016-01-31T23:00:00Z
# 516  AAL - 950  AMERICAN AIRLINES INC     Internacional  2016-01-31T23:10:00Z
#
#              Partida.Real      Chegada.Prevista          Chegada.Real  \
# 92   2016-02-01T12:13:00Z  2016-02-01T21:30:00Z  2016-02-01T21:30:00Z
# 87   2016-02-01T08:58:00Z  2016-02-01T10:35:00Z  2016-02-01T10:35:00Z
# 889  2016-01-31T22:35:00Z  2016-02-01T09:25:00Z  2016-02-01T09:25:00Z
# 671                   NaN  2016-02-01T09:11:00Z                   NaN
# 516  2016-01-31T23:10:00Z  2016-02-01T09:00:00Z  2016-02-01T09:00:00Z
#
#     Situacao.Voo                              Codigo.Justificativa  \
# ...

# %%
# Usando o sort_value para classificar mais de uma coluna , seja por ordem crescente ou decrescente
data.sort_values(['Chegada.Prevista','Chegada.Real'],ascending=[True,True]).head()
# Out:
#           Voos        Companhia.Aerea Codigo.Tipo.Linha      Partida.Prevista  \
# 119  AAL - 213  AMERICAN AIRLINES INC     Internacional  2016-01-01T00:29:00Z
# 613  AAL - 964  AMERICAN AIRLINES INC     Internacional  2016-01-01T02:38:00Z
# 271  AAL - 273  AMERICAN AIRLINES INC     Internacional  2016-01-01T00:54:00Z
# 794  AAL - 995  AMERICAN AIRLINES INC     Internacional  2016-01-01T00:55:00Z
# 369  AAL - 905  AMERICAN AIRLINES INC     Internacional  2016-01-01T00:49:00Z
#
#              Partida.Real      Chegada.Prevista          Chegada.Real  \
# 119  2016-01-01T00:29:00Z  2016-01-01T07:56:00Z  2016-01-01T07:56:00Z
# 613  2016-01-01T02:09:00Z  2016-01-01T08:04:00Z  2016-01-01T07:26:00Z
# 271  2016-01-01T00:52:00Z  2016-01-01T08:56:00Z  2016-01-01T08:03:00Z
# 794  2016-01-01T02:46:00Z  2016-01-01T09:25:00Z  2016-01-01T10:51:00Z
# 369  2016-01-01T00:49:00Z  2016-01-01T09:27:00Z  2016-01-01T09:27:00Z
#
# ...

# %%
data['LongDest'].mean()
# Out:
# -74.46471278000001

# %%
data.describe()
# Out:
#         LongDest    LatDest   LongOrig    LatOrig
# count   5.000000   5.000000   5.000000   5.000000
# mean  -74.464713  14.637997 -50.774801 -29.101321
# std    13.019132  24.949751   0.895724   1.994913
# min   -80.287046 -29.993473 -51.175381 -29.993473
# 25%   -80.287046  25.795865 -51.175381 -29.993473
# 50%   -80.287046  25.795865 -51.175381 -29.993473
# 75%   -80.287046  25.795865 -51.175381 -29.993473
# max   -51.175381  25.795865 -49.172481 -25.532713

# %%
#Usando Like para selecionar colunas
data.filter(like= 'eal').head()
# Out:
#            Partida.Real          Chegada.Real
# 0  2016-01-30T08:58:00Z  2016-01-30T10:35:00Z
# 1  2016-01-13T12:13:00Z  2016-01-13T21:30:00Z
# 2  2016-01-29T12:13:00Z  2016-01-29T21:30:00Z
# 3  2016-01-18T12:03:00Z  2016-01-18T20:41:00Z
# 4  2016-01-30T12:13:00Z  2016-01-30T21:30:00Z

# %%
#http://jonathansoma.com/lede/foundations/classes/pandas%20columns%20and%20functions/apply-a-function-to-every-row-in-a-pandas-dataframe/

# %%
# MATHPLOTLIB
#Quantidade de vôos por rota
import matplotlib.pyplot as plt
data['Pais.Destino'].value_counts().plot.bar(title= 'Quantidade de voos para Pais de Destino',edgecolor="black")

# %%
#Concentração de vôos por aeroporto.
import matplotlib.pyplot as plt
data['Aeroporto.Origem'].value_counts().plot.barh(title= 'Concentração de vôos por aeroporto',edgecolor="black")
